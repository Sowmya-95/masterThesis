# %%
from datasets import Dataset, Features, ClassLabel, Sequence, Value
from transformers import AutoTokenizer
from collections import defaultdict
import copy
import json
import os

# Load the Indic BERT tokenizer
tokenizer = AutoTokenizer.from_pretrained("ai4bharat/indic-bert", keep_accents=True)

MAX_LENGTH = 128

# Function to tokenize and align labels
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples['words'],
        padding='max_length',
        truncation=True,
        max_length=MAX_LENGTH,
        is_split_into_words=True
    )

    labels = []
    for i, label in enumerate(examples['labels']):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        label_ids = [-100] * len(word_ids)
        previous_word_idx = None
        for idx, word_idx in enumerate(word_ids):
            if word_idx is None:
                continue
            if word_idx != previous_word_idx:
                if word_idx < len(label):
                    label_ids[idx] = label[word_idx]
                else:
                    label_ids[idx] = -100  # Ignore tokens that don't have a corresponding label
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs['labels'] = labels
    return tokenized_inputs

# Function to gather data from nested JSON files
def gather_data(directory):
    all_data = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.json'):
                path = os.path.join(root, file)
                with open(path, 'r', encoding='utf-8') as infile:
                    data = json.load(infile)
                    all_data.extend(data)
    return all_data

# Load data from the specified directories
gold_standard_directory = 'Inception_files/final_documents_clubbed_with_gold_std_ner_and_mask_ids_in_BIO_new/gold_standard'
annotator1_directory = 'Inception_files/final_documents_clubbed_with_gold_std_ner_and_mask_ids_in_BIO_new/annotator_1'
annotator2_directory = 'Inception_files/final_documents_clubbed_with_gold_std_ner_and_mask_ids_in_BIO_new/annotator_2'

gold = gather_data(gold_standard_directory)
annotator1 = gather_data(annotator1_directory)
annotator2 = gather_data(annotator2_directory)

# Combine annotator data
combined_annotator_data = annotator1 + annotator2 + gold

# Initialize a dictionary to store invalid labels and their corresponding words
invalid_label_words = defaultdict(list)

# Function to combine NER and Mask IDs into a single label
def combine_labels(data):
    for item in data:
        combined_labels = []
        for word, ner, mask in zip(item['words'], item['ner'], item['mask_ids']):
            if ner == 'O' and mask == 'O':
                combined_labels.append('O')
            elif ner == 'O' and mask != 'O':
                invalid_label = f"{ner}-{mask}"
                invalid_label_words[invalid_label].append(word)
                continue
            elif ner != 'O' and mask == 'O':
                invalid_label = f"{ner}-{mask}"
                invalid_label_words[invalid_label].append(word)
                continue
            else:
                if mask == "I-mask" or mask == "B-mask":
                    combined_label = f"{ner}-mask"
                else:
                    combined_label = f"{ner}-nomask"
                combined_labels.append(combined_label)
        item['combined_labels'] = combined_labels
    return data

# Combine labels for all datasets
combined_annotator_data = combine_labels(copy.deepcopy(combined_annotator_data))

# Extract unique combined labels from the dataset
unique_combined_labels = sorted(set(label for item in combined_annotator_data for label in item['combined_labels']))

# Create a ClassLabel feature for combined labels
combined_label_feature = ClassLabel(names=unique_combined_labels)

# Convert the combined labels to integers and create the id_to_label mapping
id_to_label = {index: label for index, label in enumerate(unique_combined_labels)}
label_to_id = {label: index for index, label in enumerate(unique_combined_labels)}

# Convert the combined labels to integers using the label_to_id mapping
for item in combined_annotator_data:
    item['labels'] = [label_to_id[label] for label in item['combined_labels']]

# Define features for the dataset
features = Features({
    'words': Sequence(feature=Value(dtype='string', id=None), length=-1),
    'labels': Sequence(feature=combined_label_feature, length=-1)
})

# Create a Dataset for the combined annotator data
combined_dataset = Dataset.from_dict({
    'words': [item['words'] for item in combined_annotator_data],
    'labels': [item['labels'] for item in combined_annotator_data]
}, features=features)

# Tokenize the combined dataset
tokenized_combined_dataset = combined_dataset.map(tokenize_and_align_labels, batched=True)
# Out:
# /data/homes/skamathr/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map: 100%|██████████| 7952/7952 [00:00<00:00, 10649.51 examples/s]

# %%
import torch
from transformers import AutoModelForTokenClassification, TrainingArguments, Trainer, DataCollatorForTokenClassification, EarlyStoppingCallback
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, f1_score
import json
from collections import defaultdict
from sklearn.model_selection import KFold
import os
import evaluate
import numpy as np


# Define the model
model_checkpoint = "ai4bharat/indic-bert"
model = AutoModelForTokenClassification.from_pretrained(model_checkpoint, num_labels=len(unique_combined_labels))

# Move model to the correct device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(device)

# Define early stopping callback
early_stopping = EarlyStoppingCallback(early_stopping_patience=2)

# Load the seqeval metric
metric = evaluate.load("seqeval", trust_remote_code=True)

# Global storage for true and predicted labels
all_true_labels = []
all_pred_labels = []
all_texts = []

# Compute metrics function
def compute_metrics(p):
    global all_true_labels, all_pred_labels
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [id_to_label[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [id_to_label[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    # Flatten the list of lists for metric calculation
    flat_true_labels = [label for sublist in true_labels for label in sublist]
    flat_pred_labels = [label for sublist in true_predictions for label in sublist]

    # Compute precision, recall, f1-score for each class
    precision, recall, f1, support = precision_recall_fscore_support(
        flat_true_labels, flat_pred_labels, labels=list(id_to_label.values()), zero_division=0)

    # Compute macro F1 score
    macro_f1 = f1_score(flat_true_labels, flat_pred_labels, average='macro', labels=list(id_to_label.values()), zero_division=0)

    # Compute accuracy
    accuracy = accuracy_score(flat_true_labels, flat_pred_labels)

    # Store for confusion matrix computation and output logging
    all_true_labels.extend(true_labels)
    all_pred_labels.extend(true_predictions)

    # Prepare results
    results = {
        "accuracy": accuracy,
        "macro_f1": macro_f1,
    }

    for i, label in enumerate(list(id_to_label.values())):
        results[f"precision_{label}"] = precision[i]
        results[f"recall_{label}"] = recall[i]
        results[f"f1_{label}"] = f1[i]
        results[f"support_{label}"] = support[i]  # Add support to understand class distribution

    return results

# Setup k-fold cross-validation
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)
fold_results = []

# Hyperparameters
best_learning_rate = 2.113201911555661e-05
best_train_epochs = 8
best_warmup_steps = 42

# Create a directory to store the results
os.makedirs('Inception_files/IndicBERT_final', exist_ok=True)

# Training loop for cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(tokenized_combined_dataset)):
    print(f"Training fold {fold+1}/{k}")
    train_subset = tokenized_combined_dataset.select(train_idx)
    val_subset = tokenized_combined_dataset.select(val_idx)

    # Define the training arguments with early stopping
    training_args = TrainingArguments(
        output_dir=f'./results_fold_{fold}',
        eval_strategy='epoch',  # Evaluate at the end of each epoch
        save_strategy='epoch',        # Save at the end of each epoch to align with evaluation
        learning_rate=best_learning_rate,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        num_train_epochs=best_train_epochs,
        weight_decay=0.01,
        warmup_steps=best_warmup_steps,
        load_best_model_at_end=True,  # Ensure the best model is loaded at the end
        metric_for_best_model='eval_loss',
        logging_dir=f'./logs_fold_{fold}',
        logging_steps=10,
        report_to='none'
    )

    # Initialize the Trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_subset,
        eval_dataset=val_subset,
        tokenizer=tokenizer,
        data_collator=DataCollatorForTokenClassification(tokenizer),
        compute_metrics=compute_metrics,
        callbacks=[early_stopping]  # Add the early stopping callback
    )

    # Train the model
    trainer.train()

    # Save the model after each fold
    trainer.save_model(f'Inception_files/IndicBERT_final/saved_models_IndicBERT/model_fold_{fold}')
    eval_results = trainer.evaluate()

    # Store the results
    fold_results.append(eval_results)

# Summarize the results across all folds
metric_accumulator = defaultdict(list)

for result in fold_results:
    for key in result.keys():
        metric_accumulator[key].append(result[key])

average_metrics = {key: np.mean(values) for key, values in metric_accumulator.items()}

print("Average metrics across all folds:")
for key, value in average_metrics.items():
    print(f"{key}: {value:.4f}")

with open("Inception_files/IndicBERT_final/detailed_metrics_IndicBERT.json", "w") as f:
    json.dump(average_metrics, f, indent=4)
# Out:
# Some weights of AlbertForTokenClassification were not initialized from the model checkpoint at ai4bharat/indic-bert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training fold 1/5
#     <div>
#
#       <progress value='6368' max='6368' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6368/6368 03:33, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Macro F1</th>
#       <th>Precision B-address-mask</th>
#       <th>Recall B-address-mask</th>
#       <th>F1 B-address-mask</th>
#       <th>Support B-address-mask</th>
#       <th>Precision B-address-nomask</th>
#       <th>Recall B-address-nomask</th>
#       <th>F1 B-address-nomask</th>
#       <th>Support B-address-nomask</th>
#       <th>Precision B-age-mask</th>
#       <th>Recall B-age-mask</th>
#       <th>F1 B-age-mask</th>
#       <th>Support B-age-mask</th>
#       <th>Precision B-amount-mask</th>
#       <th>Recall B-amount-mask</th>
#       <th>F1 B-amount-mask</th>
#       <th>Support B-amount-mask</th>
#       <th>Precision B-amount-nomask</th>
#       <th>Recall B-amount-nomask</th>
#       <th>F1 B-amount-nomask</th>
#       <th>Support B-amount-nomask</th>
#       <th>Precision B-date-mask</th>
#       <th>Recall B-date-mask</th>
#       <th>F1 B-date-mask</th>
#       <th>Support B-date-mask</th>
#       <th>Precision B-date-nomask</th>
#       <th>Recall B-date-nomask</th>
#       <th>F1 B-date-nomask</th>
#       <th>Support B-date-nomask</th>
#       <th>Precision B-marital status-nomask</th>
#       <th>Recall B-marital status-nomask</th>
#       <th>F1 B-marital status-nomask</th>
#       <th>Support B-marital status-nomask</th>
#       <th>Precision B-organization-mask</th>
#       <th>Recall B-organization-mask</th>
#       <th>F1 B-organization-mask</th>
#       <th>Support B-organization-mask</th>
#       <th>Precision B-organization-nomask</th>
#       <th>Recall B-organization-nomask</th>
#       <th>F1 B-organization-nomask</th>
#       <th>Support B-organization-nomask</th>
#       <th>Precision B-other:id-mask</th>
#       <th>Recall B-other:id-mask</th>
#       <th>F1 B-other:id-mask</th>
#       <th>Support B-other:id-mask</th>
#       <th>Precision B-other:id-nomask</th>
#       <th>Recall B-other:id-nomask</th>
#       <th>F1 B-other:id-nomask</th>
#       <th>Support B-other:id-nomask</th>
#       <th>Precision B-other:vehicle-mask</th>
#       <th>Recall B-other:vehicle-mask</th>
#       <th>F1 B-other:vehicle-mask</th>
#       <th>Support B-other:vehicle-mask</th>
#       <th>Precision B-person-mask</th>
#       <th>Recall B-person-mask</th>
#       <th>F1 B-person-mask</th>
#       <th>Support B-person-mask</th>
#       <th>Precision B-person-nomask</th>
#       <th>Recall B-person-nomask</th>
#       <th>F1 B-person-nomask</th>
#       <th>Support B-person-nomask</th>
#       <th>Precision B-relation-mask</th>
#       <th>Recall B-relation-mask</th>
#       <th>F1 B-relation-mask</th>
#       <th>Support B-relation-mask</th>
#       <th>Precision B-relation-nomask</th>
#       <th>Recall B-relation-nomask</th>
#       <th>F1 B-relation-nomask</th>
#       <th>Support B-relation-nomask</th>
#       <th>Precision B-time-mask</th>
#       <th>Recall B-time-mask</th>
#       <th>F1 B-time-mask</th>
#       <th>Support B-time-mask</th>
#       <th>Precision B-time-nomask</th>
#       <th>Recall B-time-nomask</th>
#       <th>F1 B-time-nomask</th>
#       <th>Support B-time-nomask</th>
#       <th>Precision I-address-mask</th>
#       <th>Recall I-address-mask</th>
#       <th>F1 I-address-mask</th>
#       <th>Support I-address-mask</th>
#       <th>Precision I-address-nomask</th>
#       <th>Recall I-address-nomask</th>
#       <th>F1 I-address-nomask</th>
#       <th>Support I-address-nomask</th>
#       <th>Precision I-age-mask</th>
#       <th>Recall I-age-mask</th>
#       <th>F1 I-age-mask</th>
#       <th>Support I-age-mask</th>
#       <th>Precision I-age-nomask</th>
#       <th>Recall I-age-nomask</th>
#       <th>F1 I-age-nomask</th>
#       <th>Support I-age-nomask</th>
#       <th>Precision I-amount-mask</th>
#       <th>Recall I-amount-mask</th>
#       <th>F1 I-amount-mask</th>
#       <th>Support I-amount-mask</th>
#       <th>Precision I-amount-nomask</th>
#       <th>Recall I-amount-nomask</th>
#       <th>F1 I-amount-nomask</th>
#       <th>Support I-amount-nomask</th>
#       <th>Precision I-date-mask</th>
#       <th>Recall I-date-mask</th>
#       <th>F1 I-date-mask</th>
#       <th>Support I-date-mask</th>
#       <th>Precision I-date-nomask</th>
#       <th>Recall I-date-nomask</th>
#       <th>F1 I-date-nomask</th>
#       <th>Support I-date-nomask</th>
#       <th>Precision I-marital status-nomask</th>
#       <th>Recall I-marital status-nomask</th>
#       <th>F1 I-marital status-nomask</th>
#       <th>Support I-marital status-nomask</th>
#       <th>Precision I-organization-mask</th>
#       <th>Recall I-organization-mask</th>
#       <th>F1 I-organization-mask</th>
#       <th>Support I-organization-mask</th>
#       <th>Precision I-organization-nomask</th>
#       <th>Recall I-organization-nomask</th>
#       <th>F1 I-organization-nomask</th>
#       <th>Support I-organization-nomask</th>
#       <th>Precision I-other:id-mask</th>
#       <th>Recall I-other:id-mask</th>
#       <th>F1 I-other:id-mask</th>
#       <th>Support I-other:id-mask</th>
#       <th>Precision I-other:id-nomask</th>
#       <th>Recall I-other:id-nomask</th>
#       <th>F1 I-other:id-nomask</th>
#       <th>Support I-other:id-nomask</th>
#       <th>Precision I-other:vehicle-mask</th>
#       <th>Recall I-other:vehicle-mask</th>
#       <th>F1 I-other:vehicle-mask</th>
#       <th>Support I-other:vehicle-mask</th>
#       <th>Precision I-person-mask</th>
#       <th>Recall I-person-mask</th>
#       <th>F1 I-person-mask</th>
#       <th>Support I-person-mask</th>
#       <th>Precision I-person-nomask</th>
#       <th>Recall I-person-nomask</th>
#       <th>F1 I-person-nomask</th>
#       <th>Support I-person-nomask</th>
#       <th>Precision I-relation-mask</th>
#       <th>Recall I-relation-mask</th>
#       <th>F1 I-relation-mask</th>
#       <th>Support I-relation-mask</th>
#       <th>Precision I-relation-nomask</th>
#       <th>Recall I-relation-nomask</th>
#       <th>F1 I-relation-nomask</th>
#       <th>Support I-relation-nomask</th>
#       <th>Precision I-time-mask</th>
#       <th>Recall I-time-mask</th>
#       <th>F1 I-time-mask</th>
#       <th>Support I-time-mask</th>
#       <th>Precision O</th>
#       <th>Recall O</th>
#       <th>F1 O</th>
#       <th>Support O</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.198600</td>
#       <td>0.149568</td>
#       <td>0.968086</td>
#       <td>0.120668</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>10</td>
#       <td>0.758065</td>
#       <td>0.865031</td>
#       <td>0.808023</td>
#       <td>163</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>45</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>31</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>44</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.650000</td>
#       <td>0.292605</td>
#       <td>0.403548</td>
#       <td>311</td>
#       <td>0.547619</td>
#       <td>0.237113</td>
#       <td>0.330935</td>
#       <td>97</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>3</td>
#       <td>0.000000</
#     <div>
#
#       <progress value='199' max='199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [199/199 00:02]
#     </div>
# Training fold 2/5
#     <div>
#
#       <progress value='4776' max='6368' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4776/6368 02:39 < 00:53, 29.89 it/s, Epoch 6/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Macro F1</th>
#       <th>Precision B-address-mask</th>
#       <th>Recall B-address-mask</th>
#       <th>F1 B-address-mask</th>
#       <th>Support B-address-mask</th>
#       <th>Precision B-address-nomask</th>
#       <th>Recall B-address-nomask</th>
#       <th>F1 B-address-nomask</th>
#       <th>Support B-address-nomask</th>
#       <th>Precision B-age-mask</th>
#       <th>Recall B-age-mask</th>
#       <th>F1 B-age-mask</th>
#       <th>Support B-age-mask</th>
#       <th>Precision B-amount-mask</th>
#       <th>Recall B-amount-mask</th>
#       <th>F1 B-amount-mask</th>
#       <th>Support B-amount-mask</th>
#       <th>Precision B-amount-nomask</th>
#       <th>Recall B-amount-nomask</th>
#       <th>F1 B-amount-nomask</th>
#       <th>Support B-amount-nomask</th>
#       <th>Precision B-date-mask</th>
#       <th>Recall B-date-mask</th>
#       <th>F1 B-date-mask</th>
#       <th>Support B-date-mask</th>
#       <th>Precision B-date-nomask</th>
#       <th>Recall B-date-nomask</th>
#       <th>F1 B-date-nomask</th>
#       <th>Support B-date-nomask</th>
#       <th>Precision B-marital status-nomask</th>
#       <th>Recall B-marital status-nomask</th>
#       <th>F1 B-marital status-nomask</th>
#       <th>Support B-marital status-nomask</th>
#       <th>Precision B-organization-mask</th>
#       <th>Recall B-organization-mask</th>
#       <th>F1 B-organization-mask</th>
#       <th>Support B-organization-mask</th>
#       <th>Precision B-organization-nomask</th>
#       <th>Recall B-organization-nomask</th>
#       <th>F1 B-organization-nomask</th>
#       <th>Support B-organization-nomask</th>
#       <th>Precision B-other:id-mask</th>
#       <th>Recall B-other:id-mask</th>
#       <th>F1 B-other:id-mask</th>
#       <th>Support B-other:id-mask</th>
#       <th>Precision B-other:id-nomask</th>
#       <th>Recall B-other:id-nomask</th>
#       <th>F1 B-other:id-nomask</th>
#       <th>Support B-other:id-nomask</th>
#       <th>Precision B-other:vehicle-mask</th>
#       <th>Recall B-other:vehicle-mask</th>
#       <th>F1 B-other:vehicle-mask</th>
#       <th>Support B-other:vehicle-mask</th>
#       <th>Precision B-person-mask</th>
#       <th>Recall B-person-mask</th>
#       <th>F1 B-person-mask</th>
#       <th>Support B-person-mask</th>
#       <th>Precision B-person-nomask</th>
#       <th>Recall B-person-nomask</th>
#       <th>F1 B-person-nomask</th>
#       <th>Support B-person-nomask</th>
#       <th>Precision B-relation-mask</th>
#       <th>Recall B-relation-mask</th>
#       <th>F1 B-relation-mask</th>
#       <th>Support B-relation-mask</th>
#       <th>Precision B-relation-nomask</th>
#       <th>Recall B-relation-nomask</th>
#       <th>F1 B-relation-nomask</th>
#       <th>Support B-relation-nomask</th>
#       <th>Precision B-time-mask</th>
#       <th>Recall B-time-mask</th>
#       <th>F1 B-time-mask</th>
#       <th>Support B-time-mask</th>
#       <th>Precision B-time-nomask</th>
#       <th>Recall B-time-nomask</th>
#       <th>F1 B-time-nomask</th>
#       <th>Support B-time-nomask</th>
#       <th>Precision I-address-mask</th>
#       <th>Recall I-address-mask</th>
#       <th>F1 I-address-mask</th>
#       <th>Support I-address-mask</th>
#       <th>Precision I-address-nomask</th>
#       <th>Recall I-address-nomask</th>
#       <th>F1 I-address-nomask</th>
#       <th>Support I-address-nomask</th>
#       <th>Precision I-age-mask</th>
#       <th>Recall I-age-mask</th>
#       <th>F1 I-age-mask</th>
#       <th>Support I-age-mask</th>
#       <th>Precision I-age-nomask</th>
#       <th>Recall I-age-nomask</th>
#       <th>F1 I-age-nomask</th>
#       <th>Support I-age-nomask</th>
#       <th>Precision I-amount-mask</th>
#       <th>Recall I-amount-mask</th>
#       <th>F1 I-amount-mask</th>
#       <th>Support I-amount-mask</th>
#       <th>Precision I-amount-nomask</th>
#       <th>Recall I-amount-nomask</th>
#       <th>F1 I-amount-nomask</th>
#       <th>Support I-amount-nomask</th>
#       <th>Precision I-date-mask</th>
#       <th>Recall I-date-mask</th>
#       <th>F1 I-date-mask</th>
#       <th>Support I-date-mask</th>
#       <th>Precision I-date-nomask</th>
#       <th>Recall I-date-nomask</th>
#       <th>F1 I-date-nomask</th>
#       <th>Support I-date-nomask</th>
#       <th>Precision I-marital status-nomask</th>
#       <th>Recall I-marital status-nomask</th>
#       <th>F1 I-marital status-nomask</th>
#       <th>Support I-marital status-nomask</th>
#       <th>Precision I-organization-mask</th>
#       <th>Recall I-organization-mask</th>
#       <th>F1 I-organization-mask</th>
#       <th>Support I-organization-mask</th>
#       <th>Precision I-organization-nomask</th>
#       <th>Recall I-organization-nomask</th>
#       <th>F1 I-organization-nomask</th>
#       <th>Support I-organization-nomask</th>
#       <th>Precision I-other:id-mask</th>
#       <th>Recall I-other:id-mask</th>
#       <th>F1 I-other:id-mask</th>
#       <th>Support I-other:id-mask</th>
#       <th>Precision I-other:id-nomask</th>
#       <th>Recall I-other:id-nomask</th>
#       <th>F1 I-other:id-nomask</th>
#       <th>Support I-other:id-nomask</th>
#       <th>Precision I-other:vehicle-mask</th>
#       <th>Recall I-other:vehicle-mask</th>
#       <th>F1 I-other:vehicle-mask</th>
#       <th>Support I-other:vehicle-mask</th>
#       <th>Precision I-person-mask</th>
#       <th>Recall I-person-mask</th>
#       <th>F1 I-person-mask</th>
#       <th>Support I-person-mask</th>
#       <th>Precision I-person-nomask</th>
#       <th>Recall I-person-nomask</th>
#       <th>F1 I-person-nomask</th>
#       <th>Support I-person-nomask</th>
#       <th>Precision I-relation-mask</th>
#       <th>Recall I-relation-mask</th>
#       <th>F1 I-relation-mask</th>
#       <th>Support I-relation-mask</th>
#       <th>Precision I-relation-nomask</th>
#       <th>Recall I-relation-nomask</th>
#       <th>F1 I-relation-nomask</th>
#       <th>Support I-relation-nomask</th>
#       <th>Precision I-time-mask</th>
#       <th>Recall I-time-mask</th>
#       <th>F1 I-time-mask</th>
#       <th>Support I-time-mask</th>
#       <th>Precision O</th>
#       <th>Recall O</th>
#       <th>F1 O</th>
#       <th>Support O</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.032400</td>
#       <td>0.063104</td>
#       <td>0.984008</td>
#       <td>0.347519</td>
#       <td>0.818182</td>
#       <td>0.409091</td>
#       <td>0.545455</td>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>2</td>
#       <td>0.456522</td>
#       <td>0.954545</td>
#       <td>0.617647</td>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>24</td>
#       <td>0.829412</td>
#       <td>0.865031</td>
#       <td>0.846847</td>
#       <td>163</td>
#       <td>0.632653</td>
#       <td>0.584906</td>
#       <td>0.607843</td>
#       <td>53</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.863636</td>
#       <td>0.487179</td>
#       <td>0.622951</td>
#       <td>39</td>
#       <td>0.666667</td>
#       <td>0.800000</td>
#       <td>0.727273</td>
#       <td>45</td>
#       <td>0.515152</td>
#       <td>1.000000</td>
#       <td>0.680000</td>
#       <td>17</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.804965</td>
#       <td>0.900794</td>
#       <td>0.850187</td>
#       <td>252</td>
#       <td>0.849206</td>
#       <td>0.810606</td>
#       <td>0.829457</td>
#       <td>132</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>3</td>
#     <div>
#
#       <progress value='199' max='199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [199/199 00:02]
#     </div>
# Training fold 3/5
#     <div>
#
#       <progress value='4776' max='6368' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4776/6368 02:40 < 00:53, 29.78 it/s, Epoch 6/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Macro F1</th>
#       <th>Precision B-address-mask</th>
#       <th>Recall B-address-mask</th>
#       <th>F1 B-address-mask</th>
#       <th>Support B-address-mask</th>
#       <th>Precision B-address-nomask</th>
#       <th>Recall B-address-nomask</th>
#       <th>F1 B-address-nomask</th>
#       <th>Support B-address-nomask</th>
#       <th>Precision B-age-mask</th>
#       <th>Recall B-age-mask</th>
#       <th>F1 B-age-mask</th>
#       <th>Support B-age-mask</th>
#       <th>Precision B-amount-mask</th>
#       <th>Recall B-amount-mask</th>
#       <th>F1 B-amount-mask</th>
#       <th>Support B-amount-mask</th>
#       <th>Precision B-amount-nomask</th>
#       <th>Recall B-amount-nomask</th>
#       <th>F1 B-amount-nomask</th>
#       <th>Support B-amount-nomask</th>
#       <th>Precision B-date-mask</th>
#       <th>Recall B-date-mask</th>
#       <th>F1 B-date-mask</th>
#       <th>Support B-date-mask</th>
#       <th>Precision B-date-nomask</th>
#       <th>Recall B-date-nomask</th>
#       <th>F1 B-date-nomask</th>
#       <th>Support B-date-nomask</th>
#       <th>Precision B-marital status-nomask</th>
#       <th>Recall B-marital status-nomask</th>
#       <th>F1 B-marital status-nomask</th>
#       <th>Support B-marital status-nomask</th>
#       <th>Precision B-organization-mask</th>
#       <th>Recall B-organization-mask</th>
#       <th>F1 B-organization-mask</th>
#       <th>Support B-organization-mask</th>
#       <th>Precision B-organization-nomask</th>
#       <th>Recall B-organization-nomask</th>
#       <th>F1 B-organization-nomask</th>
#       <th>Support B-organization-nomask</th>
#       <th>Precision B-other:id-mask</th>
#       <th>Recall B-other:id-mask</th>
#       <th>F1 B-other:id-mask</th>
#       <th>Support B-other:id-mask</th>
#       <th>Precision B-other:id-nomask</th>
#       <th>Recall B-other:id-nomask</th>
#       <th>F1 B-other:id-nomask</th>
#       <th>Support B-other:id-nomask</th>
#       <th>Precision B-other:vehicle-mask</th>
#       <th>Recall B-other:vehicle-mask</th>
#       <th>F1 B-other:vehicle-mask</th>
#       <th>Support B-other:vehicle-mask</th>
#       <th>Precision B-person-mask</th>
#       <th>Recall B-person-mask</th>
#       <th>F1 B-person-mask</th>
#       <th>Support B-person-mask</th>
#       <th>Precision B-person-nomask</th>
#       <th>Recall B-person-nomask</th>
#       <th>F1 B-person-nomask</th>
#       <th>Support B-person-nomask</th>
#       <th>Precision B-relation-mask</th>
#       <th>Recall B-relation-mask</th>
#       <th>F1 B-relation-mask</th>
#       <th>Support B-relation-mask</th>
#       <th>Precision B-relation-nomask</th>
#       <th>Recall B-relation-nomask</th>
#       <th>F1 B-relation-nomask</th>
#       <th>Support B-relation-nomask</th>
#       <th>Precision B-time-mask</th>
#       <th>Recall B-time-mask</th>
#       <th>F1 B-time-mask</th>
#       <th>Support B-time-mask</th>
#       <th>Precision B-time-nomask</th>
#       <th>Recall B-time-nomask</th>
#       <th>F1 B-time-nomask</th>
#       <th>Support B-time-nomask</th>
#       <th>Precision I-address-mask</th>
#       <th>Recall I-address-mask</th>
#       <th>F1 I-address-mask</th>
#       <th>Support I-address-mask</th>
#       <th>Precision I-address-nomask</th>
#       <th>Recall I-address-nomask</th>
#       <th>F1 I-address-nomask</th>
#       <th>Support I-address-nomask</th>
#       <th>Precision I-age-mask</th>
#       <th>Recall I-age-mask</th>
#       <th>F1 I-age-mask</th>
#       <th>Support I-age-mask</th>
#       <th>Precision I-age-nomask</th>
#       <th>Recall I-age-nomask</th>
#       <th>F1 I-age-nomask</th>
#       <th>Support I-age-nomask</th>
#       <th>Precision I-amount-mask</th>
#       <th>Recall I-amount-mask</th>
#       <th>F1 I-amount-mask</th>
#       <th>Support I-amount-mask</th>
#       <th>Precision I-amount-nomask</th>
#       <th>Recall I-amount-nomask</th>
#       <th>F1 I-amount-nomask</th>
#       <th>Support I-amount-nomask</th>
#       <th>Precision I-date-mask</th>
#       <th>Recall I-date-mask</th>
#       <th>F1 I-date-mask</th>
#       <th>Support I-date-mask</th>
#       <th>Precision I-date-nomask</th>
#       <th>Recall I-date-nomask</th>
#       <th>F1 I-date-nomask</th>
#       <th>Support I-date-nomask</th>
#       <th>Precision I-marital status-nomask</th>
#       <th>Recall I-marital status-nomask</th>
#       <th>F1 I-marital status-nomask</th>
#       <th>Support I-marital status-nomask</th>
#       <th>Precision I-organization-mask</th>
#       <th>Recall I-organization-mask</th>
#       <th>F1 I-organization-mask</th>
#       <th>Support I-organization-mask</th>
#       <th>Precision I-organization-nomask</th>
#       <th>Recall I-organization-nomask</th>
#       <th>F1 I-organization-nomask</th>
#       <th>Support I-organization-nomask</th>
#       <th>Precision I-other:id-mask</th>
#       <th>Recall I-other:id-mask</th>
#       <th>F1 I-other:id-mask</th>
#       <th>Support I-other:id-mask</th>
#       <th>Precision I-other:id-nomask</th>
#       <th>Recall I-other:id-nomask</th>
#       <th>F1 I-other:id-nomask</th>
#       <th>Support I-other:id-nomask</th>
#       <th>Precision I-other:vehicle-mask</th>
#       <th>Recall I-other:vehicle-mask</th>
#       <th>F1 I-other:vehicle-mask</th>
#       <th>Support I-other:vehicle-mask</th>
#       <th>Precision I-person-mask</th>
#       <th>Recall I-person-mask</th>
#       <th>F1 I-person-mask</th>
#       <th>Support I-person-mask</th>
#       <th>Precision I-person-nomask</th>
#       <th>Recall I-person-nomask</th>
#       <th>F1 I-person-nomask</th>
#       <th>Support I-person-nomask</th>
#       <th>Precision I-relation-mask</th>
#       <th>Recall I-relation-mask</th>
#       <th>F1 I-relation-mask</th>
#       <th>Support I-relation-mask</th>
#       <th>Precision I-relation-nomask</th>
#       <th>Recall I-relation-nomask</th>
#       <th>F1 I-relation-nomask</th>
#       <th>Support I-relation-nomask</th>
#       <th>Precision I-time-mask</th>
#       <th>Recall I-time-mask</th>
#       <th>F1 I-time-mask</th>
#       <th>Support I-time-mask</th>
#       <th>Precision O</th>
#       <th>Recall O</th>
#       <th>F1 O</th>
#       <th>Support O</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.040500</td>
#       <td>0.043516</td>
#       <td>0.987435</td>
#       <td>0.469486</td>
#       <td>0.678571</td>
#       <td>0.760000</td>
#       <td>0.716981</td>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.866667</td>
#       <td>0.896552</td>
#       <td>0.881356</td>
#       <td>29</td>
#       <td>0.933333</td>
#       <td>0.700000</td>
#       <td>0.800000</td>
#       <td>20</td>
#       <td>0.931507</td>
#       <td>0.900662</td>
#       <td>0.915825</td>
#       <td>151</td>
#       <td>0.755556</td>
#       <td>0.755556</td>
#       <td>0.755556</td>
#       <td>45</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.800000</td>
#       <td>0.857143</td>
#       <td>0.827586</td>
#       <td>28</td>
#       <td>0.888889</td>
#       <td>0.869565</td>
#       <td>0.879121</td>
#       <td>46</td>
#       <td>0.642857</td>
#       <td>0.818182</td>
#       <td>0.720000</td>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.770186</td>
#       <td>0.873239</td>
#       <td>0.818482</td>
#       <td>284</td>
#       <td>0.885417</td>
#       <td>0.548387</td>
#       <td>0.677291</td>
#       <td>155</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td
#     <div>
#
#       <progress value='199' max='199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [199/199 00:02]
#     </div>
# Training fold 4/5
#     <div>
#
#       <progress value='3184' max='6368' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3184/6368 01:46 < 01:46, 29.78 it/s, Epoch 4/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Macro F1</th>
#       <th>Precision B-address-mask</th>
#       <th>Recall B-address-mask</th>
#       <th>F1 B-address-mask</th>
#       <th>Support B-address-mask</th>
#       <th>Precision B-address-nomask</th>
#       <th>Recall B-address-nomask</th>
#       <th>F1 B-address-nomask</th>
#       <th>Support B-address-nomask</th>
#       <th>Precision B-age-mask</th>
#       <th>Recall B-age-mask</th>
#       <th>F1 B-age-mask</th>
#       <th>Support B-age-mask</th>
#       <th>Precision B-amount-mask</th>
#       <th>Recall B-amount-mask</th>
#       <th>F1 B-amount-mask</th>
#       <th>Support B-amount-mask</th>
#       <th>Precision B-amount-nomask</th>
#       <th>Recall B-amount-nomask</th>
#       <th>F1 B-amount-nomask</th>
#       <th>Support B-amount-nomask</th>
#       <th>Precision B-date-mask</th>
#       <th>Recall B-date-mask</th>
#       <th>F1 B-date-mask</th>
#       <th>Support B-date-mask</th>
#       <th>Precision B-date-nomask</th>
#       <th>Recall B-date-nomask</th>
#       <th>F1 B-date-nomask</th>
#       <th>Support B-date-nomask</th>
#       <th>Precision B-marital status-nomask</th>
#       <th>Recall B-marital status-nomask</th>
#       <th>F1 B-marital status-nomask</th>
#       <th>Support B-marital status-nomask</th>
#       <th>Precision B-organization-mask</th>
#       <th>Recall B-organization-mask</th>
#       <th>F1 B-organization-mask</th>
#       <th>Support B-organization-mask</th>
#       <th>Precision B-organization-nomask</th>
#       <th>Recall B-organization-nomask</th>
#       <th>F1 B-organization-nomask</th>
#       <th>Support B-organization-nomask</th>
#       <th>Precision B-other:id-mask</th>
#       <th>Recall B-other:id-mask</th>
#       <th>F1 B-other:id-mask</th>
#       <th>Support B-other:id-mask</th>
#       <th>Precision B-other:id-nomask</th>
#       <th>Recall B-other:id-nomask</th>
#       <th>F1 B-other:id-nomask</th>
#       <th>Support B-other:id-nomask</th>
#       <th>Precision B-other:vehicle-mask</th>
#       <th>Recall B-other:vehicle-mask</th>
#       <th>F1 B-other:vehicle-mask</th>
#       <th>Support B-other:vehicle-mask</th>
#       <th>Precision B-person-mask</th>
#       <th>Recall B-person-mask</th>
#       <th>F1 B-person-mask</th>
#       <th>Support B-person-mask</th>
#       <th>Precision B-person-nomask</th>
#       <th>Recall B-person-nomask</th>
#       <th>F1 B-person-nomask</th>
#       <th>Support B-person-nomask</th>
#       <th>Precision B-relation-mask</th>
#       <th>Recall B-relation-mask</th>
#       <th>F1 B-relation-mask</th>
#       <th>Support B-relation-mask</th>
#       <th>Precision B-relation-nomask</th>
#       <th>Recall B-relation-nomask</th>
#       <th>F1 B-relation-nomask</th>
#       <th>Support B-relation-nomask</th>
#       <th>Precision B-time-mask</th>
#       <th>Recall B-time-mask</th>
#       <th>F1 B-time-mask</th>
#       <th>Support B-time-mask</th>
#       <th>Precision B-time-nomask</th>
#       <th>Recall B-time-nomask</th>
#       <th>F1 B-time-nomask</th>
#       <th>Support B-time-nomask</th>
#       <th>Precision I-address-mask</th>
#       <th>Recall I-address-mask</th>
#       <th>F1 I-address-mask</th>
#       <th>Support I-address-mask</th>
#       <th>Precision I-address-nomask</th>
#       <th>Recall I-address-nomask</th>
#       <th>F1 I-address-nomask</th>
#       <th>Support I-address-nomask</th>
#       <th>Precision I-age-mask</th>
#       <th>Recall I-age-mask</th>
#       <th>F1 I-age-mask</th>
#       <th>Support I-age-mask</th>
#       <th>Precision I-age-nomask</th>
#       <th>Recall I-age-nomask</th>
#       <th>F1 I-age-nomask</th>
#       <th>Support I-age-nomask</th>
#       <th>Precision I-amount-mask</th>
#       <th>Recall I-amount-mask</th>
#       <th>F1 I-amount-mask</th>
#       <th>Support I-amount-mask</th>
#       <th>Precision I-amount-nomask</th>
#       <th>Recall I-amount-nomask</th>
#       <th>F1 I-amount-nomask</th>
#       <th>Support I-amount-nomask</th>
#       <th>Precision I-date-mask</th>
#       <th>Recall I-date-mask</th>
#       <th>F1 I-date-mask</th>
#       <th>Support I-date-mask</th>
#       <th>Precision I-date-nomask</th>
#       <th>Recall I-date-nomask</th>
#       <th>F1 I-date-nomask</th>
#       <th>Support I-date-nomask</th>
#       <th>Precision I-marital status-nomask</th>
#       <th>Recall I-marital status-nomask</th>
#       <th>F1 I-marital status-nomask</th>
#       <th>Support I-marital status-nomask</th>
#       <th>Precision I-organization-mask</th>
#       <th>Recall I-organization-mask</th>
#       <th>F1 I-organization-mask</th>
#       <th>Support I-organization-mask</th>
#       <th>Precision I-organization-nomask</th>
#       <th>Recall I-organization-nomask</th>
#       <th>F1 I-organization-nomask</th>
#       <th>Support I-organization-nomask</th>
#       <th>Precision I-other:id-mask</th>
#       <th>Recall I-other:id-mask</th>
#       <th>F1 I-other:id-mask</th>
#       <th>Support I-other:id-mask</th>
#       <th>Precision I-other:id-nomask</th>
#       <th>Recall I-other:id-nomask</th>
#       <th>F1 I-other:id-nomask</th>
#       <th>Support I-other:id-nomask</th>
#       <th>Precision I-other:vehicle-mask</th>
#       <th>Recall I-other:vehicle-mask</th>
#       <th>F1 I-other:vehicle-mask</th>
#       <th>Support I-other:vehicle-mask</th>
#       <th>Precision I-person-mask</th>
#       <th>Recall I-person-mask</th>
#       <th>F1 I-person-mask</th>
#       <th>Support I-person-mask</th>
#       <th>Precision I-person-nomask</th>
#       <th>Recall I-person-nomask</th>
#       <th>F1 I-person-nomask</th>
#       <th>Support I-person-nomask</th>
#       <th>Precision I-relation-mask</th>
#       <th>Recall I-relation-mask</th>
#       <th>F1 I-relation-mask</th>
#       <th>Support I-relation-mask</th>
#       <th>Precision I-relation-nomask</th>
#       <th>Recall I-relation-nomask</th>
#       <th>F1 I-relation-nomask</th>
#       <th>Support I-relation-nomask</th>
#       <th>Precision I-time-mask</th>
#       <th>Recall I-time-mask</th>
#       <th>F1 I-time-mask</th>
#       <th>Support I-time-mask</th>
#       <th>Precision O</th>
#       <th>Recall O</th>
#       <th>F1 O</th>
#       <th>Support O</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.044800</td>
#       <td>0.031609</td>
#       <td>0.993000</td>
#       <td>0.646307</td>
#       <td>0.730769</td>
#       <td>0.730769</td>
#       <td>0.730769</td>
#       <td>26</td>
#       <td>0.666667</td>
#       <td>0.444444</td>
#       <td>0.533333</td>
#       <td>9</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>3</td>
#       <td>0.964286</td>
#       <td>0.900000</td>
#       <td>0.931034</td>
#       <td>30</td>
#       <td>0.904762</td>
#       <td>1.000000</td>
#       <td>0.950000</td>
#       <td>19</td>
#       <td>0.903030</td>
#       <td>0.949045</td>
#       <td>0.925466</td>
#       <td>157</td>
#       <td>0.842105</td>
#       <td>0.800000</td>
#       <td>0.820513</td>
#       <td>40</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.857143</td>
#       <td>0.833333</td>
#       <td>0.845070</td>
#       <td>36</td>
#       <td>0.968750</td>
#       <td>0.837838</td>
#       <td>0.898551</td>
#       <td>37</td>
#       <td>0.694444</td>
#       <td>0.961538</td>
#       <td>0.806452</td>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1</td>
#       <td>0.943620</td>
#       <td>0.898305</td>
#       <td>0.920405</td>
#       <td>354</td>
#       <td>0.952055</td>
#       <td>0.945578</td>
#       <td>0.948805</td>
#       <td>147</td>
#       <td>0.538462</td>
#       <td>0.875000</td>
#       <td>0.666667</td>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>8</td>
#     <div>
#
#       <progress value='199' max='199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [199/199 00:02]
#     </div>
# Training fold 5/5
#     <div>
#
#       <progress value='3980' max='6368' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3980/6368 02:13 < 01:20, 29.77 it/s, Epoch 5/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Macro F1</th>
#       <th>Precision B-address-mask</th>
#       <th>Recall B-address-mask</th>
#       <th>F1 B-address-mask</th>
#       <th>Support B-address-mask</th>
#       <th>Precision B-address-nomask</th>
#       <th>Recall B-address-nomask</th>
#       <th>F1 B-address-nomask</th>
#       <th>Support B-address-nomask</th>
#       <th>Precision B-age-mask</th>
#       <th>Recall B-age-mask</th>
#       <th>F1 B-age-mask</th>
#       <th>Support B-age-mask</th>
#       <th>Precision B-amount-mask</th>
#       <th>Recall B-amount-mask</th>
#       <th>F1 B-amount-mask</th>
#       <th>Support B-amount-mask</th>
#       <th>Precision B-amount-nomask</th>
#       <th>Recall B-amount-nomask</th>
#       <th>F1 B-amount-nomask</th>
#       <th>Support B-amount-nomask</th>
#       <th>Precision B-date-mask</th>
#       <th>Recall B-date-mask</th>
#       <th>F1 B-date-mask</th>
#       <th>Support B-date-mask</th>
#       <th>Precision B-date-nomask</th>
#       <th>Recall B-date-nomask</th>
#       <th>F1 B-date-nomask</th>
#       <th>Support B-date-nomask</th>
#       <th>Precision B-marital status-nomask</th>
#       <th>Recall B-marital status-nomask</th>
#       <th>F1 B-marital status-nomask</th>
#       <th>Support B-marital status-nomask</th>
#       <th>Precision B-organization-mask</th>
#       <th>Recall B-organization-mask</th>
#       <th>F1 B-organization-mask</th>
#       <th>Support B-organization-mask</th>
#       <th>Precision B-organization-nomask</th>
#       <th>Recall B-organization-nomask</th>
#       <th>F1 B-organization-nomask</th>
#       <th>Support B-organization-nomask</th>
#       <th>Precision B-other:id-mask</th>
#       <th>Recall B-other:id-mask</th>
#       <th>F1 B-other:id-mask</th>
#       <th>Support B-other:id-mask</th>
#       <th>Precision B-other:id-nomask</th>
#       <th>Recall B-other:id-nomask</th>
#       <th>F1 B-other:id-nomask</th>
#       <th>Support B-other:id-nomask</th>
#       <th>Precision B-other:vehicle-mask</th>
#       <th>Recall B-other:vehicle-mask</th>
#       <th>F1 B-other:vehicle-mask</th>
#       <th>Support B-other:vehicle-mask</th>
#       <th>Precision B-person-mask</th>
#       <th>Recall B-person-mask</th>
#       <th>F1 B-person-mask</th>
#       <th>Support B-person-mask</th>
#       <th>Precision B-person-nomask</th>
#       <th>Recall B-person-nomask</th>
#       <th>F1 B-person-nomask</th>
#       <th>Support B-person-nomask</th>
#       <th>Precision B-relation-mask</th>
#       <th>Recall B-relation-mask</th>
#       <th>F1 B-relation-mask</th>
#       <th>Support B-relation-mask</th>
#       <th>Precision B-relation-nomask</th>
#       <th>Recall B-relation-nomask</th>
#       <th>F1 B-relation-nomask</th>
#       <th>Support B-relation-nomask</th>
#       <th>Precision B-time-mask</th>
#       <th>Recall B-time-mask</th>
#       <th>F1 B-time-mask</th>
#       <th>Support B-time-mask</th>
#       <th>Precision B-time-nomask</th>
#       <th>Recall B-time-nomask</th>
#       <th>F1 B-time-nomask</th>
#       <th>Support B-time-nomask</th>
#       <th>Precision I-address-mask</th>
#       <th>Recall I-address-mask</th>
#       <th>F1 I-address-mask</th>
#       <th>Support I-address-mask</th>
#       <th>Precision I-address-nomask</th>
#       <th>Recall I-address-nomask</th>
#       <th>F1 I-address-nomask</th>
#       <th>Support I-address-nomask</th>
#       <th>Precision I-age-mask</th>
#       <th>Recall I-age-mask</th>
#       <th>F1 I-age-mask</th>
#       <th>Support I-age-mask</th>
#       <th>Precision I-age-nomask</th>
#       <th>Recall I-age-nomask</th>
#       <th>F1 I-age-nomask</th>
#       <th>Support I-age-nomask</th>
#       <th>Precision I-amount-mask</th>
#       <th>Recall I-amount-mask</th>
#       <th>F1 I-amount-mask</th>
#       <th>Support I-amount-mask</th>
#       <th>Precision I-amount-nomask</th>
#       <th>Recall I-amount-nomask</th>
#       <th>F1 I-amount-nomask</th>
#       <th>Support I-amount-nomask</th>
#       <th>Precision I-date-mask</th>
#       <th>Recall I-date-mask</th>
#       <th>F1 I-date-mask</th>
#       <th>Support I-date-mask</th>
#       <th>Precision I-date-nomask</th>
#       <th>Recall I-date-nomask</th>
#       <th>F1 I-date-nomask</th>
#       <th>Support I-date-nomask</th>
#       <th>Precision I-marital status-nomask</th>
#       <th>Recall I-marital status-nomask</th>
#       <th>F1 I-marital status-nomask</th>
#       <th>Support I-marital status-nomask</th>
#       <th>Precision I-organization-mask</th>
#       <th>Recall I-organization-mask</th>
#       <th>F1 I-organization-mask</th>
#       <th>Support I-organization-mask</th>
#       <th>Precision I-organization-nomask</th>
#       <th>Recall I-organization-nomask</th>
#       <th>F1 I-organization-nomask</th>
#       <th>Support I-organization-nomask</th>
#       <th>Precision I-other:id-mask</th>
#       <th>Recall I-other:id-mask</th>
#       <th>F1 I-other:id-mask</th>
#       <th>Support I-other:id-mask</th>
#       <th>Precision I-other:id-nomask</th>
#       <th>Recall I-other:id-nomask</th>
#       <th>F1 I-other:id-nomask</th>
#       <th>Support I-other:id-nomask</th>
#       <th>Precision I-other:vehicle-mask</th>
#       <th>Recall I-other:vehicle-mask</th>
#       <th>F1 I-other:vehicle-mask</th>
#       <th>Support I-other:vehicle-mask</th>
#       <th>Precision I-person-mask</th>
#       <th>Recall I-person-mask</th>
#       <th>F1 I-person-mask</th>
#       <th>Support I-person-mask</th>
#       <th>Precision I-person-nomask</th>
#       <th>Recall I-person-nomask</th>
#       <th>F1 I-person-nomask</th>
#       <th>Support I-person-nomask</th>
#       <th>Precision I-relation-mask</th>
#       <th>Recall I-relation-mask</th>
#       <th>F1 I-relation-mask</th>
#       <th>Support I-relation-mask</th>
#       <th>Precision I-relation-nomask</th>
#       <th>Recall I-relation-nomask</th>
#       <th>F1 I-relation-nomask</th>
#       <th>Support I-relation-nomask</th>
#       <th>Precision I-time-mask</th>
#       <th>Recall I-time-mask</th>
#       <th>F1 I-time-mask</th>
#       <th>Support I-time-mask</th>
#       <th>Precision O</th>
#       <th>Recall O</th>
#       <th>F1 O</th>
#       <th>Support O</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.062700</td>
#       <td>0.023679</td>
#       <td>0.994327</td>
#       <td>0.670928</td>
#       <td>0.705882</td>
#       <td>0.666667</td>
#       <td>0.685714</td>
#       <td>18</td>
#       <td>1.000000</td>
#       <td>0.375000</td>
#       <td>0.545455</td>
#       <td>8</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>4</td>
#       <td>0.869565</td>
#       <td>0.952381</td>
#       <td>0.909091</td>
#       <td>21</td>
#       <td>1.000000</td>
#       <td>0.909091</td>
#       <td>0.952381</td>
#       <td>11</td>
#       <td>0.935897</td>
#       <td>0.960526</td>
#       <td>0.948052</td>
#       <td>152</td>
#       <td>1.000000</td>
#       <td>0.851852</td>
#       <td>0.920000</td>
#       <td>54</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.850000</td>
#       <td>0.894737</td>
#       <td>0.871795</td>
#       <td>38</td>
#       <td>0.947368</td>
#       <td>0.923077</td>
#       <td>0.935065</td>
#       <td>39</td>
#       <td>0.843750</td>
#       <td>1.000000</td>
#       <td>0.915254</td>
#       <td>27</td>
#       <td>1.000000</td>
#       <td>0.142857</td>
#       <td>0.250000</td>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0</td>
#       <td>0.965517</td>
#       <td>0.916667</td>
#       <td>0.940458</td>
#       <td>336</td>
#       <td>0.972222</td>
#       <td>0.939597</td>
#       <td>0.955631</td>
#       <td>149</td>
#       <td>0.750000</td>
#       <td>1.000000</td>
#       <td>0.857143</td>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>7</td>
#     <div>
#
#       <progress value='199' max='199' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [199/199 00:02]
#     </div>
# Average metrics across all folds:
# eval_loss: 0.0493
# eval_accuracy: 0.9885
# eval_macro_f1: 0.5169
# eval_precision_B-Address-mask: 0.5997
# eval_recall_B-Address-mask: 0.5343
# eval_f1_B-Address-mask: 0.5648
# eval_support_B-Address-mask: 20.2000
# eval_precision_B-Address-nomask: 0.6000
# eval_recall_B-Address-nomask: 0.1925
# eval_f1_B-Address-nomask: 0.2822
# eval_support_B-Address-nomask: 7.8000
# eval_precision_B-Age-mask: 0.4333
# eval_recall_B-Age-mask: 0.5000
# eval_f1_B-Age-mask: 0.4476
# eval_support_B-Age-mask: 2.4000
# eval_precision_B-Amount-mask: 0.7280
# eval_recall_B-Amount-mask: 0.8873
# eval_f1_B-Amount-mask: 0.7914
# eval_support_B-Amount-mask: 23.2000
# eval_precision_B-Amount-nomask: 0.7230
# eval_recall_B-Amount-nomask: 0.5531
# eval_f1_B-Amount-nomask: 0.6207
# eval_support_B-Amount-nomask: 16.8000
# eval_precision_B-Date-mask: 0.8902
# eval_recall_B-Date-mask: 0.9109
# eval_f1_B-Date-mask: 0.9003
# eval_support_B-Date-mask: 157.2000
# eval_precision_B-Date-nomask: 0.7717
# eval_recall_B-Date-nomask: 0.6566
# eval_f1_B-Date-nomask: 0.6960
# eval_support_B-Date-nomask: 47.4000
# eval_precision_B-Marital status-nomask: 0.0000
# eval_recall_B-Marital status-nomask: 0.0000
# eval_f1_B-Marital status-nomask: 0.0000
# eval_support_B-Marital status-nomask: 0.2000
# eval_precision_B-Organization-mask: 0.7541
# eval_recall_B-Organization-mask: 0.7745
# eval_f1_B-Organization-mask: 0.7634
# eval_support_B-Organization-mask: 34.4000
# eval_precision_B-Organization-nomask: 0.8433
# eval_recall_B-Organization-nomask: 0.8092
# eval_f1_B-Organization-nomask: 0.8233
# eval_support_B-Organization-nomask: 42.2000
# eval_precision_B-Other:ID-mask: 0.6590
# eval_recall_B-Other:ID-mask: 0.8705
# eval_f1_B-Other:ID-mask: 0.7455
# eval_support_B-Other:ID-mask: 22.0000
# eval_precision_B-Other:ID-nomask: 0.4000
# eval_recall_B-Other:ID-nomask: 0.0821
# eval_f1_B-Other:ID-nomask: 0.1333
# eval_support_B-Other:ID-nomask: 8.2000
# eval_precision_B-Other:vehicle-mask: 0.0000
# eval_recall_B-Other:vehicle-mask: 0.0000
# eval_f1_B-Other:vehicle-mask: 0.0000
# eval_support_B-Other:vehicle-mask: 0.2000
# eval_precision_B-Person-mask: 0.8705
# eval_recall_B-Person-mask: 0.8605
# eval_f1_B-Person-mask: 0.8633
# eval_support_B-Person-mask: 307.4000
# eval_precision_B-Person-nomask: 0.8775
# eval_recall_B-Person-nomask: 0.8091
# eval_f1_B-Person-nomask: 0.8415
# eval_support_B-Person-nomask: 136.0000
# eval_precision_B-Relation-mask: 0.2679
# eval_recall_B-Relation-mask: 0.2917
# eval_f1_B-Relation-mask: 0.2788
# eval_support_B-Relation-mask: 6.6000
# eval_precision_B-Relation-nomask: 0.0000
# eval_recall_B-Relation-nomask: 0.0000
# eval_f1_B-Relation-nomask: 0.0000
# eval_support_B-Relation-nomask: 4.4000
# eval_precision_B-Time-mask: 0.7200
# eval_recall_B-Time-mask: 0.7667
# eval_f1_B-Time-mask: 0.7318
# eval_support_B-Time-mask: 4.0000
# eval_precision_B-Time-nomask: 0.0000
# eval_recall_B-Time-nomask: 0.0000
# eval_f1_B-Time-nomask: 0.0000
# eval_support_B-Time-nomask: 0.2000
# eval_precision_I-Address-mask: 0.8003
# eval_recall_I-Address-mask: 0.8021
# eval_f1_I-Address-mask: 0.7974
# eval_support_I-Address-mask: 64.0000
# eval_precision_I-Address-nomask: 0.2000
# eval_recall_I-Address-nomask: 0.1429
# eval_f1_I-Address-nomask: 0.1667
# eval_support_I-Address-nomask: 7.4000
# eval_precision_I-Age-mask: 0.3357
# eval_recall_I-Age-mask: 0.5000
# eval_f1_I-Age-mask: 0.3971
# eval_support_I-Age-mask: 2.8000
# eval_precision_I-Age-nomask: 0.0000
# eval_recall_I-Age-nomask: 0.0000
# eval_f1_I-Age-nomask: 0.0000
# eval_support_I-Age-nomask: 0.4000
# eval_precision_I-Amount-mask: 0.8027
# eval_recall_I-Amount-mask: 0.8899
# eval_f1_I-Amount-mask: 0.8324
# eval_support_I-Amount-mask: 49.0000
# eval_precision_I-Amount-nomask: 0.9209
# eval_recall_I-Amount-nomask: 0.7269
# eval_f1_I-Amount-nomask: 0.7604
# eval_support_I-Amount-nomask: 35.8000
# eval_precision_I-Date-mask: 0.9099
# eval_recall_I-Date-mask: 0.9700
# eval_f1_I-Date-mask: 0.9379
# eval_support_I-Date-mask: 163.8000
# eval_precision_I-Date-nomask: 0.7067
# eval_recall_I-Date-nomask: 0.5722
# eval_f1_I-Date-nomask: 0.6106
# eval_support_I-Date-nomask: 16.4000
# eval_precision_I-Marital status-nomask: 0.0000
# eval_recall_I-Marital status-nomask: 0.0000
# eval_f1_I-Marital status-nomask: 0.0000
# eval_support_I-Marital status-nomask: 0.2000
# eval_precision_I-Organization-mask: 0.8035
# eval_recall_I-Organization-mask: 0.8435
# eval_f1_I-Organization-mask: 0.8203
# eval_support_I-Organization-mask: 107.2000
# eval_precision_I-Organization-nomask: 0.8637
# eval_recall_I-Organization-nomask: 0.8092
# eval_f1_I-Organization-nomask: 0.8322
# eval_support_I-Organization-nomask: 103.8000
# eval_precision_I-Other:ID-mask: 0.7270
# eval_recall_I-Other:ID-mask: 0.8932
# eval_f1_I-Other:ID-mask: 0.7859
# eval_support_I-Other:ID-mask: 29.2000
# eval_precision_I-Other:ID-nomask: 0.4000
# eval_recall_I-Other:ID-nomask: 0.1535
# eval_f1_I-Other:ID-nomask: 0.2139
# eval_support_I-Other:ID-nomask: 12.0000
# eval_precision_I-Other:vehicle-mask: 0.0000
# eval_recall_I-Other:vehicle-mask: 0.0000
# eval_f1_I-Other:vehicle-mask: 0.0000
# eval_support_I-Other:vehicle-mask: 0.2000
# eval_precision_I-Person-mask: 0.8595
# eval_recall_I-Person-mask: 0.8602
# eval_f1_I-Person-mask: 0.8589
# eval_support_I-Person-mask: 476.8000
# eval_precision_I-Person-nomask: 0.8899
# eval_recall_I-Person-nomask: 0.8214
# eval_f1_I-Person-nomask: 0.8531
# eval_support_I-Person-nomask: 175.2000
# eval_precision_I-Relation-mask: 0.0000
# eval_recall_I-Relation-mask: 0.0000
# eval_f1_I-Relation-mask: 0.0000
# eval_support_I-Relation-mask: 0.4000
# eval_precision_I-Relation-nomask: 0.0000
# eval_recall_I-Relation-nomask: 0.0000
# eval_f1_I-Relation-nomask: 0.0000
# eval_support_I-Relation-nomask: 0.6000
# eval_precision_I-Time-mask: 0.8578
# eval_recall_I-Time-mask: 0.8476
# eval_f1_I-Time-mask: 0.8134
# eval_support_I-Time-mask: 9.0000
# eval_precision_O: 0.9954
# eval_recall_O: 0.9970
# eval_f1_O: 0.9962
# eval_support_O: 37982.4000
# eval_runtime: 2.3594
# eval_samples_per_second: 674.0868
# eval_steps_per_second: 84.3456
# epoch: 5.8000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Function to plot confusion matrix
def plot_confusion_matrix(true_labels, pred_labels, label_list, output_path):
    # Flatten the list of lists to get all labels
    flat_true_labels = [item for sublist in true_labels for item in sublist]
    flat_pred_labels = [item for sublist in pred_labels for item in sublist]

    # Compute the confusion matrix
    cm = confusion_matrix(flat_true_labels, flat_pred_labels, labels=label_list)

    # Normalize the confusion matrix
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Plot the confusion matrix
    plt.figure(figsize=(30, 30))
    sns.heatmap(cm, annot=True, fmt='.2%', cmap='viridis', xticklabels=label_list, yticklabels=label_list)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Normalized Confusion Matrix for IndicBERT')
    plt.savefig(output_path)
    plt.show()

# Plot the confusion matrix for all collected true and predicted labels
plot_confusion_matrix(all_true_labels, all_pred_labels, list(id_to_label.values()), "Inception_files/IndicBERT_final/confusion_matrix_IndicBERT.png")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

# Function to plot confusion matrix with custom annotations
def plot_confusion_matrix(true_labels, pred_labels, label_list, output_path, threshold=1.5):
    # Flatten the list of lists to get all labels
    flat_true_labels = [item for sublist in true_labels for item in sublist]
    flat_pred_labels = [item for sublist in pred_labels for item in sublist]

    # Compute the confusion matrix
    cm = confusion_matrix(flat_true_labels, flat_pred_labels, labels=label_list)

    # Normalize the confusion matrix
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Custom annotation function
    def annotate(values, threshold):
        return [f"{value:.2%}" if value >= threshold / 100 else "" for value in values]  # Display values greater than threshold

    # Create custom annotations
    annotations = np.array([annotate(row, threshold) for row in cm_normalized])

    # Plot the confusion matrix
    plt.figure(figsize=(30, 30))
    sns.heatmap(cm_normalized, annot=annotations, fmt='', cmap='viridis', xticklabels=label_list, yticklabels=label_list)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Normalized Confusion Matrix for IndicBERT')
    plt.savefig(output_path)
    plt.show()

# Plot the confusion matrix for all collected true and predicted labels
plot_confusion_matrix(all_true_labels, all_pred_labels, list(id_to_label.values()), "Inception_files/IndicBERT_final/confusion_matrix_IndicBERt_noZeros.png")

# %% [markdown]
# ## Prediction

# %%
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification
from datasets import load_metric, ClassLabel, Sequence, Dataset, Features, Value


# Load the Indic BERT tokenizer and model path
model_path = "Inception_files/IndicBERT_final/saved_models_IndicBERT_withManana/model_fold_4"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForTokenClassification.from_pretrained(model_path)
model.to('cuda' if torch.cuda.is_available() else 'cpu')
model.eval()

# Adjust predict_and_mask to do predictions
def predict_and_mask(text, tokenizer, models, id_to_label):
    tokenized_sentence = tokenizer(text, return_tensors="pt")
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    tokenized_sentence = {k: v.to(device) for k, v in tokenized_sentence.items()}

    with torch.no_grad():
        outputs = model(**tokenized_sentence)
        logits = outputs.logits

    # Predict the final labels using argmax
    predictions = torch.argmax(logits, dim=-1)
    predictions = predictions[0].cpu().numpy()  # Convert to numpy array and remove batch dimension


    # Convert prediction IDs to labels
    predicted_labels = [id_to_label[id] for id in predictions]

    # Prepare the masked text
    tokens = tokenizer.convert_ids_to_tokens(tokenized_sentence["input_ids"][0])
    masked_text = []
    for i, (token, label) in enumerate(zip(tokens, predicted_labels)):
        if label != 'O' and 'mask' in label:
            # Add [MASK] but avoid adding it at sentence boundaries
            if 0 < i < len(tokens) - 1:
                masked_text.append("****")
        else:
            # Append the actual token, adjusting if it's a subword
            masked_text.append(token.replace("##", ""))

    # Convert tokens back to string, ensuring to clean up tokenization spaces
    masked_text = tokenizer.convert_tokens_to_string(masked_text)
    return masked_text


# Legal text for prediction
legal_text = """मोहम्मद अलाउद्दीन खान
अन्य बनाम बिहार राज्य और अन्य" वाले मामले में इस न्यायालय के
निर्णय पर अवलंब लेते हुए उच्च न्यायालय ने इस बात पर जोर दिया कि दंड
प्रक्रिया संहिता की धारा 482 के अधीन शक्तियों का प्रयोग करते समय
और/या उन्‍्मोचन के चरण में न्यायालय के पास सीमित अधिकार क्षेत्र है
"""

masked_text = predict_and_mask(legal_text, tokenizer, models, id_to_label)
print("Original:", legal_text)
print("Masked:", masked_text)
print("\n")
# Out:
# Original: मोहम्मद अलाउद्दीन खान
# अन्य बनाम बिहार राज्य और अन्य" वाले मामले में इस न्यायालय के
# निर्णय पर अवलंब लेते हुए उच्च न्यायालय ने इस बात पर जोर दिया कि दंड
# प्रक्रिया संहिता की धारा 482 के अधीन शक्तियों का प्रयोग करते समय
# और/या उन्‍्मोचन के चरण में न्यायालय के पास सीमित अधिकार क्षेत्र है
#
# Masked: **************** अन्य बनाम******** और अन्य" वाले मामले में इस न्यायालय के निर्णय पर अवलंब लेते हुए उच्च न्यायालय ने इस बात पर जोर दिया कि दंड प्रक्रिया संहिता की धारा 482 के अधीन शक्तियों का प्रयोग करते समय और/या उन् ्मोचन के चरण में न्यायालय के पास सीमित अधिकार क्षेत्र है
